# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import glob

files = glob.glob("/content/drive/MyDrive/Colab Notebooks/LegalAIDatasets/1. textdata/3.2_clean_parquet/*.parquet")

print("Total files:", len(files))
print(files[:5])  # show first 5
# Out:
# Total files: 6
# ['/content/drive/MyDrive/Colab Notebooks/LegalAIDatasets/1. textdata/3.2_clean_parquet/cleaned_1.parquet', '/content/drive/MyDrive/Colab Notebooks/LegalAIDatasets/1. textdata/3.2_clean_parquet/cleaned_2.parquet', '/content/drive/MyDrive/Colab Notebooks/LegalAIDatasets/1. textdata/3.2_clean_parquet/cleaned_3.parquet', '/content/drive/MyDrive/Colab Notebooks/LegalAIDatasets/1. textdata/3.2_clean_parquet/cleaned_4.parquet', '/content/drive/MyDrive/Colab Notebooks/LegalAIDatasets/1. textdata/3.2_clean_parquet/cleaned_5.parquet']

# %%
import pandas as pd

df = pd.read_parquet(files[5])

print(df.shape)   # rows, columns
print(df.columns) # column names
df.head(5)
# Out:
# (19747, 4)
# Index(['id', 'text', 'source', 'media_type'], dtype='object')
#        id                                               text   source  \
# 0  pq_6_0  349 F.Supp.2d 1160 (2003) Janice WALTERS, et a...  parquet
# 1  pq_6_1  748 F.Supp.2d 1268 (2009) Robert BONADEO, an i...  parquet
# 2  pq_6_2  349 F.Supp.2d 736 (2004) DAVENTREE LIMITED and...  parquet
# 3  pq_6_3  771 F.Supp.2d 569 (2011) FIRST NATIONAL INSURA...  parquet
# 4  pq_6_4  740 F.Supp.2d 759 (2010) Donald Raymond BARBE,...  parquet
#
#   media_type
# 0       text
# 1       text
# 2       text
# 3       text
# 4       text
